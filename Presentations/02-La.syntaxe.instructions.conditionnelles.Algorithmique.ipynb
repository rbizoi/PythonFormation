# %% [markdown]
# # SI ALORS SINON

# %%
ciel = input("Entrez le ciel : soleil, couvert ou pluie ?")
temperature = input("Entrez la température : elevee ou normale ?")
pluie = input("Entrer le vent : fort ou faible ?")
if ciel == "couvert" :
	print("Nous restons à l'intérieur")
elif ciel == "soleil" :
	if temperature == "normale" :
		print("Nous sortons dehors")
	elif temperature == "elevee" :
		print("Nous restons à l'intérieur")
elif ciel == "pluie" :
	if vent == "faible" :
		print("Nous sortons dehors")
	elif vent == "fort" :
		print("Nous restons à l'intérieur")
# Out:
# Entrez le ciel : soleil, couvert ou pluie ? soleil
# Entrez la température : elevee ou normale ? elevee
# Entrer le vent : fort ou faible ? faible
# Nous restons à l'intérieur

# %%
ciel = input("Entrez le ciel : soleil, couvert ou pluie ?")
temperature = input("Entrez la température : elevee ou normale ?")
pluie = input("Entrer le vent : fort ou faible ?")
if (ciel == 'soleil' and temperature == 'normale') or (ciel == 'pluie' and vent == 'faible') :
	print("Nous sortons dehors")
else :
	print("Nous restons à l'intérieur")
# Out:
# Entrez le ciel : soleil, couvert ou pluie ? couvert
# Entrez la température : elevee ou normale ? normale
# Entrer le vent : fort ou faible ? fort
# Nous restons à l'intérieur

# %% [markdown]
# # Opérateur ternaire

# %%
age = int(input("Entrer votre âge"))
res = 'mineur' if age < 18 else 'majeur'
print("Vous êtes", res)
# Out:
# Entrer votre âge 61
# Vous êtes majeur

# %% [markdown]
# # ECRIRE en Python

# %%
a = 1
x = 8.7
s = "hello"
print("mes variables sont a avec la valeur", a, 'b avec la valeur',b,'et s =',s)
# affiche mes variables sont a avec la valeur 1 b avec la valeur 8.7 et s hello
print("a sans espace par defaut", a, sep='')
# affiche a sans espace par defaut1
print("sans saut ", end="")
print("de ligne")
# affiche saut de ligne
# Out:
# mes variables sont a avec la valeur 1 b avec la valeur 2 et s = hello
# a sans espace par defaut1
# sans saut de ligne

# %% [markdown]
# # CAS PARMI

# %%
mois = int(input('Entrer une entier entre 1 et 6 :'))
if mois == 1 :
	print('Janvier')
elif mois == 2 :
	print('Férvrier')
elif mois == 3 :
	print('Mars')
elif mois == 4 :
	print('Avril')
elif mois == 5 :
	print('Mai')
else :
	print('Juin')
# Out:
# Entrer une entier entre 1 et 6 : 4
# Avril
